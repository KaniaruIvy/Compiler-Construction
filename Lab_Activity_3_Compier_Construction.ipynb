# %% [markdown]
# <a href="https://colab.research.google.com/github/KaniaruIvy/Compiler-Construction/blob/main/Lab_Activity_3_Compier_Construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lab 3**
#
# Group Members:
# * 118751-Amugo Tatyana
# * 118465-Maccine Quincy
# * 115774-Kaniaru Ivy
# * 120190-Lusiji Lyvia
# * 120304-Owira Keith
#
# **Instructions:**
# Review the structure of the Flex input file.
#
# Thereafter, develop a simple lexer by developing your own Flex input file.

# %% [markdown]
# ```
# /*1) This is the definitions section*/
# /* Declaring two counters one for number
# of lines other for number of characters */
# %{
# int number_lines = 0;
# int number_of_chars = 0;
# %}
# /*2) This is the rule section*/
# /***rule 1 counts the number of lines,
# rule 2 counts the number of characters
# and rule 3 specifies when to stop
# taking input***/
# %%
# \n	 ++number_lines;
# .	 ++number_of_chars;
# end	 return 0;
# %%
#
# /*** 3) User code section***/
# int yywrap(){}
# int main(int argc, char **argv)
# {
# /* 4) Subroutines section */
# yylex();
# printf("number of lines = %d, number of chars = %d\n",
# 	number_lines, number_of_chars );
#
# return 0;
# }
#
# ```
#
#
# ![Screenshot (489).png](data:image/png;base64,...)
